# %%
############# liblaryのimport ################
import aplpy
import matplotlib.pyplot as plt

########################################## FITSの読み込み #############################################
fig = plt.figure(figsize = (10,10))
f1 = aplpy.FITSFigure("Cloverleaf_rob0_CO_3-2_mom0_-500to500_abs.fits", figure=fig, subplot=(2,2,1))
f2 = aplpy.FITSFigure("same_obs_header_*image_abs.fits", figure=fig, subplot=(2,2,2))
f3 = aplpy.FITSFigure("same_obs_header_*residual_abs.fits", figure=fig, subplot=(2,2,3))
f4 = aplpy.FITSFigure("same_obs_header_*source3_abs.fits", figure=fig, subplot=(2,2,4))

########## 間隔を調節 ##########
plt.subplots_adjust(wspace=0.05, hspace=0.2)

################################################## f1 ################################################
########## glay scaleにしたい場合 ##########
# f1.show_grayscale(invert = 'set_theme',vmin =-0.05 ,vmax=1.5)  # 引数に'set_theme'で色の反転 # MAX/MINの設定はここ
########## color scaleにしたい場合 ##########
f1.show_colorscale(vmin =0 ,vmax=0.002) # 引数に何も指定しなければ、勝手に調整してくれる。(MAX/MINをとってくれる？) # カラースケールのMAX/MINの設定はここ

########## color barの設置 ##########
f1.add_colorbar() # 設置の有無
# f1.colorbar.set_location('right') # カラーバーの位置、選択肢→(right,left,top,under)
# f1.colorbar.set_width(0.2) # カラーバーの幅
# f1.colorbar.set_axis_label_text('Intensity (Jy/beam)') # カラーバーのラベルの追加

########## 軸ラベル(軸の名前)の設置 ##########
# f1.axis_labels.show() #軸ラベルあり
f1.axis_labels.hide() #軸ラベルなし
# f1.axis_labels.show_x() # X軸ラベルあり
# f1.axis_labels.hide_x() # X軸ラベルなし
# f1.axis_labels.show_y() # Y軸ラベルあり
# f1.axis_labels.hide_y() # Y軸ラベルなし
# f1.axis_labels.set_xtext('Right Ascension (J2000)') # X軸ラベルの名称の設定
# f1.axis_labels.set_ytext('Declination (J2000)') # Y軸ラベルの名称の設定

########## メモリの設置 ##########
f1.tick_labels.show() # メモリあり
# f1.tick_labels.hide() # メモリなし

########## Beamサイズの設置 ##########
# f1.add_beam() # beamサイズの有無
# f1.beam.set_frame(True) # Beamのフレームの有無
# f1.beam.set_color('black') # Beamの色
# f1.beam.set_edgecolor('black') # Beamサイズを表示するフレームの色
# f1.beam.set_facecolor('black') # フレーム内の色

########## ラベル(図内の文字)の設置 ##########
# f1.add_label(0.17, 0.95, '(a) observation', relative=True)

########## Scale barの設置 ##########
# f1.add_scalebar(0.00003) # ()でスケールを設定*この時、FITSによって単位が異なる。大体の場合は、arcsec/degree
# f1.scalebar.set_frame(True) # スケールバーを囲むフレームの有無
# f1.scalebar.set_label( '0.1" ') # スケールのラベルの設定
# f1.scalebar.set_corner('top right') # どこにスケールバーを置くかを設定

########## 図のタイトルの設定 ##########
# f1.set_title('test') 

################################################## f2 ################################################
########## glay scaleにしたい場合 ##########
# f2.show_grayscale(invert = 'set_theme',vmin =-0.05 ,vmax=1.5)  # 引数に'set_theme'で色の反転 # MAX/MINの設定はここ
########## color scaleにしたい場合 ##########
f2.show_colorscale(vmin =0 ,vmax=0.002) # 引数に何も指定しなければ、勝手に調整してくれる。(MAX/MINをとってくれる？) # カラースケールのMAX/MINの設定はここ

########## color barの設置 ##########
f2.add_colorbar() # 設置の有無
# f2.colorbar.set_location('right') # カラーバーの位置、選択肢→(right,left,top,under)
# f2.colorbar.set_width(0.2) # カラーバーの幅
# f2.colorbar.set_axis_label_text('Intensity (Jy/beam)') # カラーバーのラベルの追加

########## 軸ラベル(軸の名前)の設置 ##########
# f2.axis_labels.show() #軸ラベルあり
f2.axis_labels.hide() #軸ラベルなし
# f2.axis_labels.show_x() # X軸ラベルあり
# f2.axis_labels.hide_x() # X軸ラベルなし
# f2.axis_labels.show_y() # Y軸ラベルあり
# f2.axis_labels.hide_y() # Y軸ラベルなし
# f2.axis_labels.set_xtext('Right Ascension (J2000)') # X軸ラベルの名称の設定
# f2.axis_labels.set_ytext('Declination (J2000)') # Y軸ラベルの名称の設定

########## メモリの設置 ##########
f2.tick_labels.show() # メモリあり
# f2.tick_labels.hide() # メモリなし

########## Beamサイズの設置 ##########
# f2.add_beam() # beamサイズの有無
# f2.beam.set_frame(True) # Beamのフレームの有無
# f2.beam.set_color('black') # Beamの色
# f2.beam.set_edgecolor('black') # Beamサイズを表示するフレームの色
# f2.beam.set_facecolor('black') # フレーム内の色

########## ラベル(図内の文字)の設置 ##########
# f2.add_label(0.17, 0.95, '(a) observation', relative=True)

########## Scale barの設置 ##########
# f2.add_scalebar(0.00003) # ()でスケールを設定*この時、FITSによって単位が異なる。大体の場合は、arcsec/degree
# f2.scalebar.set_frame(True) # スケールバーを囲むフレームの有無
# f2.scalebar.set_label( '0.1" ') # スケールのラベルの設定
# f2.scalebar.set_corner('top right') # どこにスケールバーを置くかを設定

########## 図のタイトルの設定 ##########
# f2.set_title('test') 

################################################## f3 ################################################
########## glay scaleにしたい場合 ##########
# f3.show_grayscale(invert = 'set_theme',vmin =-0.05 ,vmax=1.5)  # 引数に'set_theme'で色の反転 # MAX/MINの設定はここ
########## color scaleにしたい場合 ##########
f3.show_colorscale(vmin =0 ,vmax=0.002) # 引数に何も指定しなければ、勝手に調整してくれる。(MAX/MINをとってくれる？) # カラースケールのMAX/MINの設定はここ

########## color barの設置 ##########
f3.add_colorbar() # 設置の有無
# f3.colorbar.set_location('right') # カラーバーの位置、選択肢→(right,left,top,under)
# f3.colorbar.set_width(0.2) # カラーバーの幅
# f3.colorbar.set_axis_label_text('Intensity (Jy/beam)') # カラーバーのラベルの追加

########## 軸ラベル(軸の名前)の設置 ##########
# f3.axis_labels.show() #軸ラベルあり
f3.axis_labels.hide() #軸ラベルなし
# f3.axis_labels.show_x() # X軸ラベルあり
# f3.axis_labels.hide_x() # X軸ラベルなし
# f3.axis_labels.show_y() # Y軸ラベルあり
# f3.axis_labels.hide_y() # Y軸ラベルなし
# f3.axis_labels.set_xtext('Right Ascension (J2000)') # X軸ラベルの名称の設定
# f3.axis_labels.set_ytext('Declination (J2000)') # Y軸ラベルの名称の設定

########## メモリの設置 ##########
f3.tick_labels.show() # メモリあり
# f3.tick_labels.hide() # メモリなし

########## Beamサイズの設置 ##########
# f3.add_beam() # beamサイズの有無
# f3.beam.set_frame(True) # Beamのフレームの有無
# f3.beam.set_color('black') # Beamの色
# f3.beam.set_edgecolor('black') # Beamサイズを表示するフレームの色
# f3.beam.set_facecolor('black') # フレーム内の色

########## ラベル(図内の文字)の設置 ##########
# f3.add_label(0.17, 0.95, '(a) observation', relative=True)

########## Scale barの設置 ##########
# f3.add_scalebar(0.00003) # ()でスケールを設定*この時、FITSによって単位が異なる。大体の場合は、arcsec/degree
# f3.scalebar.set_frame(True) # スケールバーを囲むフレームの有無
# f3.scalebar.set_label( '0.1" ') # スケールのラベルの設定
# f3.scalebar.set_corner('top right') # どこにスケールバーを置くかを設定

########## 図のタイトルの設定 ##########
# f3.set_title('test') 

################################################## f4 ################################################
########## glay scaleにしたい場合 ##########
# f4.show_grayscale(invert = 'set_theme',vmin =-0.05 ,vmax=1.5)  # 引数に'set_theme'で色の反転 # MAX/MINの設定はここ
########## color scaleにしたい場合 ##########
f4.show_colorscale(vmin =0 ,vmax=0.002) # 引数に何も指定しなければ、勝手に調整してくれる。(MAX/MINをとってくれる？) # カラースケールのMAX/MINの設定はここ

########## color barの設置 ##########
f4.add_colorbar() # 設置の有無
# f4.colorbar.set_location('right') # カラーバーの位置、選択肢→(right,left,top,under)
# f4.colorbar.set_width(0.2) # カラーバーの幅
# f4.colorbar.set_axis_label_text('Intensity (Jy/beam)') # カラーバーのラベルの追加

########## 軸ラベル(軸の名前)の設置 ##########
# f4.axis_labels.show() #軸ラベルあり
f4.axis_labels.hide() #軸ラベルなし
# f4.axis_labels.show_x() # X軸ラベルあり
# f4.axis_labels.hide_x() # X軸ラベルなし
# f4.axis_labels.show_y() # Y軸ラベルあり
# f4.axis_labels.hide_y() # Y軸ラベルなし
# f4.axis_labels.set_xtext('Right Ascension (J2000)') # X軸ラベルの名称の設定
# f4.axis_labels.set_ytext('Declination (J2000)') # Y軸ラベルの名称の設定

########## メモリの設置 ##########
f4.tick_labels.show() # メモリあり
# f4.tick_labels.hide() # メモリなし

########## Beamサイズの設置 ##########
# f4.add_beam() # beamサイズの有無
# f4.beam.set_frame(True) # Beamのフレームの有無
# f4.beam.set_color('black') # Beamの色
# f4.beam.set_edgecolor('black') # Beamサイズを表示するフレームの色
# f4.beam.set_facecolor('black') # フレーム内の色

########## ラベル(図内の文字)の設置 ##########
# f4.add_label(0.17, 0.95, '(a) observation', relative=True)

########## Scale barの設置 ##########
# f4.add_scalebar(0.00003) # ()でスケールを設定*この時、FITSによって単位が異なる。大体の場合は、arcsec/degree
# f4.scalebar.set_frame(True) # スケールバーを囲むフレームの有無
# f4.scalebar.set_label( '0.1" ') # スケールのラベルの設定
# f4.scalebar.set_corner('top right') # どこにスケールバーを置くかを設定

########## 図のタイトルの設定 ##########
# f4.set_title('test') 

##################################################### Save ###########################################
plt.savefig('fig.png')
